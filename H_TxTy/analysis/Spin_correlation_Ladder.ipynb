# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_eqJ','SpinXY_eqJ','SpinT_eqJ','Green_eqJ','Den_eqJ']
RK=['R','K']
for i in range(4):
    path='/home/juan/Documents/Projects/QMC_tests/H_TxTy/data/Lx_14_Ly_2_ty_2021-05-22-15-33-58/Lx_14_Ly_2_ty_'+str(i)+'/'

    filename=path+Options[2]+RK[0]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')


    ##processing coordinates
    xx=np.array(lines[::2])[:,0]
    yy=np.array(lines[::2])[:,1]
    x=list(set(list(np.array(lines[::2])[:,0])))
    y=list(set(list(np.array(lines[::2])[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    orbsalph=np.array(lines[1::2])[:,0]
    orbsbet=np.array(lines[1::2])[:,1]
    real=np.array(lines[1::2])[:,2]
    realerr=np.array(lines[1::2])[:,3]
    im=np.array(lines[1::2])[:,4]
    imerr=np.array(lines[1::2])[:,5]


    ##plots

    NLx=14
    NLy=2
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    imsq=np.reshape(im,[NLx,NLy])
    #plt.imshow(imsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()

    NLx=14
    NLy=2
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    realsq=np.reshape(real,[NLx,NLy])
    #plt.imshow(realsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()
    plt.plot(Nplx[6:]-6,realsq.T[0][6:],label=str(i))
    plt.scatter(Nplx[6:]-6,realsq.T[0][6:])
plt.legend()
plt.show()

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_eqJ','SpinXY_eqJ','SpinT_eqJ','Green_eqJ','Den_eqJ']
RK=['R','K']
for i in range(3):
    path='/home/juan/Documents/Projects/QMC_tests/H_TxTy/data/Beta_10_Lx_14_Ly_2_ty_2021-05-22-20-00-58/Beta_10_Lx_14_Ly_2_ty_'+str(i)+'/'

    filename=path+Options[2]+RK[0]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')


    ##processing coordinates
    xx=np.array(lines[::2])[:,0]
    yy=np.array(lines[::2])[:,1]
    x=list(set(list(np.array(lines[::2])[:,0])))
    y=list(set(list(np.array(lines[::2])[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    orbsalph=np.array(lines[1::2])[:,0]
    orbsbet=np.array(lines[1::2])[:,1]
    real=np.array(lines[1::2])[:,2]
    realerr=np.array(lines[1::2])[:,3]
    im=np.array(lines[1::2])[:,4]
    imerr=np.array(lines[1::2])[:,5]


    ##plots

    NLx=14
    NLy=2
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    imsq=np.reshape(im,[NLx,NLy])
    #plt.imshow(imsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()

    NLx=14
    NLy=2
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    realsq=np.reshape(real,[NLx,NLy])
    #plt.imshow(realsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()
    plt.plot(Nplx[6:]-6,realsq.T[0][6:],label=str(i))
    plt.scatter(Nplx[6:]-6,realsq.T[0][6:])
plt.ylim([-0.6,1])
plt.xlim([-0.1,7.1])
plt.legend()
plt.show()
