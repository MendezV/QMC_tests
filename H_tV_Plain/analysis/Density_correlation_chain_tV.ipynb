# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_eqJ','SpinXY_eqJ','SpinT_eqJ','Green_eqJ','Den_eqJ']
RK=['R','K']
for i in [1.0,2.0,2.5]:
    #path='/home/juan/Documents/Projects/QMC_tests/H_tV_Plain/data/StafusaLHVO_tV_L1_28_L2_1_V_2021-05-26-11-34-22/StafusaLHVO_tV_L1_28_L2_1_V_'
    path='../data/StafusaLHVO_tV_L1_28_L2_1_V_2021-05-26-11-34-22/StafusaLHVO_tV_L1_28_L2_1_V_'
    path=path+str(i)+'/'

    filename=path+Options[-1]+RK[0]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')


    ##processing coordinates
    xx=np.array(lines[::2])[:,0]
    yy=np.array(lines[::2])[:,1]
    x=list(set(list(np.array(lines[::2])[:,0])))
    y=list(set(list(np.array(lines[::2])[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    orbsalph=np.array(lines[1::2])[:,0]
    orbsbet=np.array(lines[1::2])[:,1]
    real=np.array(lines[1::2])[:,2]
    realerr=np.array(lines[1::2])[:,3]
    im=np.array(lines[1::2])[:,4]
    imerr=np.array(lines[1::2])[:,5]


    ##plots

    NLx=28
    NLy=1
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    imsq=np.reshape(im,[NLx,NLy])
    #plt.imshow(imsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()

    NLx=28
    NLy=1
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    realsq=np.reshape(real,[NLx,NLy])
    #plt.imshow(realsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()
    NNN=int(NLx/2)-1
    plt.plot(Nplx[NNN:]-NNN,realsq.T[0][NNN:],label=str(i))
    plt.scatter(Nplx[NNN:]-NNN,realsq.T[0][NNN:])
    #plt.plot(Nplx,realsq.T[0],label=str(i))
    #plt.scatter(Nplx,realsq.T[0])
    print(realsq.T[0][6:])
    plt.xlim([-0.1,14.1])
    plt.ylim([-0.25,0.25])

plt.xlabel(r'$r/a$', size=20)
plt.ylabel(r'$\langle n(r)n(0) \rangle$', size=20)
plt.legend()
plt.show()
# Out:
# [-0.00676745  0.00636824 -0.01122422  0.01126298 -0.02496218  0.02761227
#  -0.1251948   0.25       -0.1251948   0.02761227 -0.02496218  0.01126298
#  -0.01122422  0.00636824 -0.00676745  0.00437975 -0.0048071   0.0033915
#  -0.0038766   0.00292448 -0.00339026  0.00272879]
# [-0.02466586  0.02625549 -0.03368178  0.03747755 -0.05286743  0.06197654
#  -0.14828254  0.25       -0.14828254  0.06197654 -0.05286743  0.03747755
#  -0.03368178  0.02625549 -0.02466586  0.02148366 -0.02130056  0.01950509
#  -0.01950806  0.01824059 -0.0187422   0.01862195]
# [-0.05149293  0.05313169 -0.06022394  0.06392416 -0.077298    0.08642783
#  -0.1629225   0.25       -0.1629225   0.08642783 -0.077298    0.06392416
#  -0.06022394  0.05313169 -0.05149293  0.04865662 -0.04801293  0.0473565
#  -0.04773786  0.04877027 -0.05042828  0.04983358]

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_eqJ','SpinXY_eqJ','SpinT_eqJ','Green_eqJ','Den_eqJ']
RK=['R','K']
for i in [1.0,2.0,2.5]:
    path='/home/juan/Documents/Projects/QMC_tests/H_tV_Plain/data/tV_L1_28_L2_1_V_2021-05-26-10-45-24/tV_L1_28_L2_1_V_'
    path=path+str(i)+'/'

    filename=path+Options[-1]+RK[0]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')


    ##processing coordinates
    xx=np.array(lines[::2])[:,0]
    yy=np.array(lines[::2])[:,1]
    x=list(set(list(np.array(lines[::2])[:,0])))
    y=list(set(list(np.array(lines[::2])[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    orbsalph=np.array(lines[1::2])[:,0]
    orbsbet=np.array(lines[1::2])[:,1]
    real=np.array(lines[1::2])[:,2]
    realerr=np.array(lines[1::2])[:,3]
    im=np.array(lines[1::2])[:,4]
    imerr=np.array(lines[1::2])[:,5]


    ##plots

    NLx=28
    NLy=1
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    imsq=np.reshape(im,[NLx,NLy])
    #plt.imshow(imsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()

    NLx=28
    NLy=1
    Nplx=np.arange(NLx)
    Nply=np.arange(NLy)
    realsq=np.reshape(real,[NLx,NLy])
    #plt.imshow(realsq)
    #plt.xticks(Nplx,xpl)
    #plt.yticks(Nply,ypl)
    #plt.show()
    NNN=int(NLx/2)-1
    plt.plot(Nplx[NNN:]-NNN,realsq.T[0][NNN:],label=str(i))
    plt.scatter(Nplx[NNN:]-NNN,realsq.T[0][NNN:])
    #plt.plot(Nplx,realsq.T[0],label=str(i))
    #plt.scatter(Nplx,realsq.T[0])
    print(realsq.T[0][6:])
    plt.xlim([-0.1,14.1])
    plt.ylim([-0.25,0.25])
plt.legend()
plt.show()
# Out:
# [-0.00676745  0.00636824 -0.01122422  0.01126298 -0.02496218  0.02761227
#  -0.1251948   0.25       -0.1251948   0.02761227 -0.02496218  0.01126298
#  -0.01122422  0.00636824 -0.00676745  0.00437975 -0.0048071   0.0033915
#  -0.0038766   0.00292448 -0.00339026  0.00272879]
# [-0.02466586  0.02625549 -0.03368178  0.03747755 -0.05286743  0.06197654
#  -0.14828254  0.25       -0.14828254  0.06197654 -0.05286743  0.03747755
#  -0.03368178  0.02625549 -0.02466586  0.02148366 -0.02130056  0.01950509
#  -0.01950806  0.01824059 -0.0187422   0.01862195]
# [-0.05149293  0.05313169 -0.06022394  0.06392416 -0.077298    0.08642783
#  -0.1629225   0.25       -0.1629225   0.08642783 -0.077298    0.06392416
#  -0.06022394  0.05313169 -0.05149293  0.04865662 -0.04801293  0.0473565
#  -0.04773786  0.04877027 -0.05042828  0.04983358]
