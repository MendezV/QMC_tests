# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_tauJ','SpinXY_tauJ','SpinT_tauJ','Green_tauJ','Den_tauJ','Current_tauJ']
RK=['R','K']
LATSZ=[10]
#path_pr='/Users/jfmv/Documents/Proyectos/QMC_tests/H_current/data/'
path_pr='/home/juan/Documents/Projects/QMC_tests/H_current/data/'
path_pr=path_pr+'Fig5_SWZ_test_2021-06-02-11-14-29/Fig5_SWZ_test_'


for i in LATSZ:
    path=path_pr+str(i)+'/'
    filename=path+Options[-1]+RK[1]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')

    ##processing coordinates
    xx=np.array(lines)[:,0]
    yy=np.array(lines)[:,1]
    x=list(set(list(np.array(lines)[:,0])))
    y=list(set(list(np.array(lines)[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    real=np.array(lines)[:,2]
    realerr=np.array(lines)[:,3]
    im=np.array(lines)[:,4]
    imerr=np.array(lines)[:,5]

    ##plots
    print("Imaginary...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    imsq=np.reshape(im,[NL,NL])
    imerrsq=np.reshape(imerr,[NL,NL])
    plt.imshow(imsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,imsq[i_tr,:],imsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,imsq[:,j_tr],imsq[:,j_tr], fmt='o')
    plt.show()
    
    print("Real...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    realsq=np.reshape(real,[NL,NL])
    realerrsq=np.reshape(realerr,[NL,NL])
    plt.imshow(realsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,realsq[i_tr,:],realsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,realsq[:,j_tr],realsq[:,j_tr], fmt='o')
    plt.show()
# Out:
# Imaginary... 10 x 10
# x... 0.0
# y... 0.0
# Real... 10 x 10
# x... 0.0
# y... 0.0

# %% [markdown]
# # Density

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_tauJ','SpinXY_tauJ','SpinT_tauJ','Green_tauJ','Den_tauJ','Current_tauJ']
RK=['R','K']
LATSZ=[10]
#path_pr='/Users/jfmv/Documents/Proyectos/QMC_tests/H_current/data/'
path_pr='/home/juan/Documents/Projects/QMC_tests/H_current/data/'
path_pr=path_pr+'Fig5_SWZ_test_2021-06-02-11-14-29/Fig5_SWZ_test_'


for i in LATSZ:
    path=path_pr+str(i)+'/'
    filename=path+Options[4]+RK[1]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')

    ##processing coordinates
    xx=np.array(lines)[:,0]
    yy=np.array(lines)[:,1]
    x=list(set(list(np.array(lines)[:,0])))
    y=list(set(list(np.array(lines)[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    real=np.array(lines)[:,2]
    realerr=np.array(lines)[:,3]
    im=np.array(lines)[:,4]
    imerr=np.array(lines)[:,5]

    ##plots
    print("Imaginary...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    imsq=np.reshape(im,[NL,NL])
    imerrsq=np.reshape(imerr,[NL,NL])
    plt.imshow(imsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,imsq[i_tr,:],imsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('x...',ypl[j_tr])
    plt.errorbar(xpl,imsq[:,j_tr],imsq[:,j_tr], fmt='o')
    plt.show()
    
    print("Real...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    realsq=np.reshape(real,[NL,NL])
    realerrsq=np.reshape(realerr,[NL,NL])
    plt.imshow(realsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,realsq[i_tr,:],realsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,realsq[:,j_tr],realsq[:,j_tr], fmt='o')
    plt.show()
# Out:
# Imaginary... 10 x 10
# x... 0.0
# x... 0.0
# Real... 10 x 10
# x... 0.0
# x... 0.0

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_tauJ','SpinXY_tauJ','SpinT_tauJ','Green_tauJ','Den_tauJ','Current_tauJ']
RK=['R','K']
LATSZ=[6]
#path_pr='/Users/jfmv/Documents/Proyectos/QMC_tests/H_current/data/'
path_pr='/home/juan/Documents/Projects/QMC_tests/H_current/data/'
path_pr=path_pr+'Fig5_SWZ_binsweeps_2021-06-02-12-54-02/Fig5_SWZ_binsweeps_'


for i in LATSZ:
    path=path_pr+str(i)+'/'
    filename=path+Options[4]+RK[1]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')

    ##processing coordinates
    xx=np.array(lines)[:,0]
    yy=np.array(lines)[:,1]
    x=list(set(list(np.array(lines)[:,0])))
    y=list(set(list(np.array(lines)[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    real=np.array(lines)[:,2]
    realerr=np.array(lines)[:,3]
    im=np.array(lines)[:,4]
    imerr=np.array(lines)[:,5]

    ##plots
    print("Imaginary...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    imsq=np.reshape(im,[NL,NL])
    imerrsq=np.reshape(imerr,[NL,NL])
    plt.imshow(imsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,imsq[i_tr,:],imsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,imsq[:,j_tr],imsq[:,j_tr], fmt='o')
    plt.show()
    
    print("Real...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    realsq=np.reshape(real,[NL,NL])
    realerrsq=np.reshape(realerr,[NL,NL])
    plt.imshow(realsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,realsq[i_tr,:],realsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,realsq[:,j_tr],realsq[:,j_tr], fmt='o')
    plt.show()
    
    print(realsq[:,j_tr])
# Out:
# Imaginary... 6 x 6
# x... 0.0
# y... 0.0
# Real... 6 x 6
# x... 0.0
# y... 0.0
# [0.10100879 0.06811266 0.01054914 0.06811266 0.10100879 0.11478128]

# %%
#path='/home/juan/Programs/ALF/pyALF/Scripts/ALF_data'
Options=['SpinZ_tauJ','SpinXY_tauJ','SpinT_tauJ','Green_tauJ','Den_tauJ','Current_tauJ']
RK=['R','K']
LATSZ=[6]
#path_pr='/Users/jfmv/Documents/Proyectos/QMC_tests/H_current/data/'
path_pr='/home/juan/Documents/Projects/QMC_tests/H_current/data/'
path_pr=path_pr+'Fig5_SWZ_binsweeps_2021-06-02-13-09-20/Fig5_SWZ_binsweeps_'


for i in LATSZ:
    path=path_pr+str(i)+'/'
    filename=path+Options[4]+RK[1]
    f=open(filename, 'r')

    lines=[]
    for line in f:
        l=[]
        l=[float(i) for i in (line.strip()).split()]
        lines.append(l)
        #print(line,'s')

    ##processing coordinates
    xx=np.array(lines)[:,0]
    yy=np.array(lines)[:,1]
    x=list(set(list(np.array(lines)[:,0])))
    y=list(set(list(np.array(lines)[:,1])))
    x.sort()
    y.sort()
    xpl=[round(i,3) for i in x]
    ypl=[round(i,3) for i in y]

    ## getting values if the correlation functions
    real=np.array(lines)[:,2]
    realerr=np.array(lines)[:,3]
    im=np.array(lines)[:,4]
    imerr=np.array(lines)[:,5]

    ##plots
    print("Imaginary...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    imsq=np.reshape(im,[NL,NL])
    imerrsq=np.reshape(imerr,[NL,NL])
    plt.imshow(imsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,imsq[i_tr,:],imsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,imsq[:,j_tr],imsq[:,j_tr], fmt='o')
    plt.show()
    
    print("Real...",i,"x",i)
    NL=int(np.sqrt(np.size(xx)))
    Npl=np.arange(NL)
    realsq=np.reshape(real,[NL,NL])
    realerrsq=np.reshape(realerr,[NL,NL])
    plt.imshow(realsq)
    plt.xticks(Npl,xpl)
    plt.yticks(Npl,ypl)
    plt.show()
    
    i_tr=int(NL/2 -1)
    print('x...',xpl[i_tr])
    plt.errorbar(ypl,realsq[i_tr,:],realsq[i_tr,:], fmt='o')
    plt.show()
    
    j_tr=int(NL/2 -1)
    print('y...',ypl[j_tr])
    plt.errorbar(xpl,realsq[:,j_tr],realsq[:,j_tr], fmt='o')
    plt.show()
    
    print(realsq[:,j_tr])
# Out:
# Imaginary... 6 x 6
# x... 0.0
# y... 0.0
# Real... 6 x 6
# x... 0.0
# y... 0.0
# [0.09754526 0.07120828 0.00425642 0.07120828 0.09754526 0.11020947]
